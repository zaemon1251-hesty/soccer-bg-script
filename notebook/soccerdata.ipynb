# %%
import logging
import warnings
from pathlib import Path

import pandas as pd
import soccerdata as sd

logging.basicConfig(level=logging.ERROR)
warnings.filterwarnings("ignore")

# %%
sd.FBref.available_leagues()
# Out:
# ['Big 5 European Leagues Combined',
#  'ENG-Premier League',
#  'ESP-La Liga',
#  'FRA-Ligue 1',
#  'GER-Bundesliga',
#  'INT-European Championship',
#  "INT-Women's World Cup",
#  'INT-World Cup',
#  'ITA-Serie A']

# %%
leagues = ["Big 5 European Leagues Combined"]
seasons = [14, 15, 16, 17, 18, 19]
fb = sd.FBref(leagues=leagues, seasons=seasons, proxy="tor", data_dir=Path("/Users/heste/workspace/soccernet/sn-script/database/fbref"), no_cache=False)
# Out:
# [03/23/25 16:31:17] INFO     Saving cached data to                                                   ]8;id=298530;file:///Users/heste/workspace/soccernet/sn-script/.venv/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=312495;file:///Users/heste/workspace/soccernet/sn-script/.venv/lib/python3.10/site-packages/soccerdata/_common.py#263\263]8;;\
#                              /Users/heste/workspace/soccernet/sn-script/database/fbref

# %%
schedule = fb.read_schedule()
schedule.head(30)
# Out:
#                                                                     week  day  \
# league             season game
# ENG-Premier League 1415   2014-08-16 Arsenal-Crystal Palace            1  Sat
#                           2014-08-16 Leicester City-Everton            1  Sat
#                           2014-08-16 Manchester Utd-Swansea City       1  Sat
#                           2014-08-16 QPR-Hull City                     1  Sat
#                           2014-08-16 Stoke City-Aston Villa            1  Sat
#                           2014-08-16 West Brom-Sunderland              1  Sat
#                           2014-08-16 West Ham-Tottenham                1  Sat
#                           2014-08-17 Liverpool-Southampton             1  Sun
#                           2014-08-17 Newcastle Utd-Manchester City     1  Sun
#                           2014-08-18 Burnley-Chelsea                   1  Mon
#                           2014-08-23 Aston Villa-Newcastle Utd         2  Sat
# ...

# %%
fbref_stat_types = [
    "standard",
    "keeper",
    "keeper_adv",
    "shooting",
    "passing",
    "passing_types",
    "goal_shot_creation",
    "defense",
    "possession",
    "playing_time",
    "misc"
]

# %%
for stat_type in fbref_stat_types:
    print(stat_type)
    team_season_stats = fb.read_team_season_stats(stat_type)
# Out:
# standard
# keeper
# keeper_adv
# shooting
# passing
# passing_types
# goal_shot_creation
# defense
# possession
# playing_time
# misc

# %%
for stat_type in fbref_stat_types:
    if stat_type not in ["standard", "league"]:
        # ないらしい
        continue
    team_match_stats = fb.read_team_match_stats(stat_type)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       2 if stat_type == "standard":
#       3     # ないらしい
#       4     continue
# ----> 5 team_match_stats = fb.read_team_match_stats(stat_type)
#
# File ~/workspace/soccernet/sn-script/.venv/lib/python3.10/site-packages/soccerdata/fbref.py:494, in FBref.read_team_match_stats(self, stat_type, opponent_stats, team, force_cache)
#     490     stats.append(df_table)
#     492 # return data frame
#     493 df = (
# --> 494     _concat(stats, key=["league", "season", "team"])
#     495     .replace(
#     496         {
#     497             "Opponent": TEAMNAME_REPLACEMENTS,
#     498         }
#     499     )
#     500     .rename(columns={"Comp": "league"})
#     501     .pipe(self._translate_league)
#     502     .pipe(
#     503         standardize_colnames,
#     504         cols=[
# ...

# %%
for stat_type in fbref_stat_types:
    print(stat_type)
    player_season_stats = fb.read_player_season_stats(stat_type)
# Out:
# standard
# [03/18/25 22:51:18] ERROR    Error while scraping                                                    ]8;id=532836;file:///Users/heste/workspace/soccernet/sn-script/.venv/lib/python3.10/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=1174;file:///Users/heste/workspace/soccernet/sn-script/.venv/lib/python3.10/site-packages/soccerdata/_common.py#545\545]8;;\
#                              https://fbref.com/en/comps/Big5/2014-2015/stats/players/2014-2015-Big-5
#                              -European-Leagues-Stats. Retrying... (attempt 1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "/Users/heste/workspace/soccernet/sn-script/.venv/lib/python3.10/site-p
#                              ackages/soccerdata/_common.py", line 525, in _download_and_save
#                                  response.raise_for_status()
#                                File
# ...

# %%
logging.getLogger().setLevel(logging.ERROR)

match_stat_types = [
    "summary",
    "keepers",
    "passing",
    "passing_types",
    "defense",
    "possession",
    "misc"
]

# match_idはgame_idと同一
for stat_type in match_stat_types:
    print(stat_type)
    player_match_stats = fb.read_player_match_stats(stat_type)
# Out:
#                                                                                                    jersey_number  \
#
# league             season game                              team           player
# ENG-Premier League 1415   2014-08-16 Arsenal-Crystal Palace Arsenal        Aaron Ramsey                       16
#                                                                            Alex Oxlade-Chamberlain            15
#                                                                            Alexis Sánchez                      7
#                                                                            Calum Chambers                     21
#                                                                            Jack Wilshere                      10
#                                                                            Kieran Gibbs                        3
# ...
